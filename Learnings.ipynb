# %%
time='hi9 all this raman'
print(id(time))
a=time
a+=('and rahul')
print(id(a))
# Out:
# 2361540252144
# 2361528630720

# %%
#list
t=[]#this is an empty list , List allow multiple data type
#eg:
lst = [1,2,3,'pavneet',10.4]

print(lst[3])
print(lst[3])
# Out:
# pavneet

# %%
a = [[],[[[],[[],[34,'ansrk']]]]]
# krsna


b = [[23,[[],[],[[[[],[],[[34,56,89]]]]]]]]
# 56

c = ['Syntax','found',[[[[34,43,43]],[[],['Nice','error']]]]]
#error

print('a: ',a[1][0][1][1][1][-1::-1])

print('b: ',b[0][1][2][0][0][2][0][1]) 

print('c: ',c[2][0][1][1][1])
# Out:
# a:  krsna
# b:  56
# c:  error

# %%
#dir('list')
# Ordered
# Mutable
# Allows duplicates
# elements index
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 2
#       1 #dir('list')
# ----> 2 Ordered
#
# NameError: name 'Ordered' is not defined

# %%
classs=['a','a','a','a','c','d']
print('classs=[\'a\',\'c\',\'d\']\n',classs)
classs.append('e')
print("append('e')\n",classs,'//After Append')
classs.insert(4,'b')
print("insert(4,'b')\n",classs,'//After Insert')
c2=['f','g']
classs.extend(c2)
print("c2=['f','g']\nextend(c2)\n",classs,'//After Extend')
classs.pop(-3)
print("pop(-3)\n",classs,'//After Pop')
print("count(1)\n",classs.count('a'),'//Count Result')
# Out:
# classs=['a','c','d']
#  ['a', 'a', 'a', 'a', 'c', 'd']
# append('e')
#  ['a', 'a', 'a', 'a', 'c', 'd', 'e'] //After Append
# insert(4,'b')
#  ['a', 'a', 'a', 'a', 'b', 'c', 'd', 'e'] //After Insert
# c2=['f','g']
# extend(c2)
#  ['a', 'a', 'a', 'a', 'b', 'c', 'd', 'e', 'f', 'g'] //After Extend
# pop(-3)
#  ['a', 'a', 'a', 'a', 'b', 'c', 'd', 'f', 'g'] //After Pop
# count(1)
#  4 //Count Result

# %%
a=[1,2,77,4,5]
sum = 0
for i in a:
    sum += i
print(sum)

d=[45,75,[[]],[]]

print(type[d[1]])
# Out:
# 89
# type[75]

# %%
alphabets = list('abcdefghijklmnopqrstuvwxyz')
text = "Hello"
print("Poses of alphabets in ordering:\n")
for i in text:
    letter = alphabets.index(i.lower())
    print(i," -> ",alphabets.index(i.lower()))
# Out:
# Poses of alphabets in ordering:
#
# H  ->  7
# e  ->  4
# l  ->  11
# l  ->  11
# o  ->  14

# %%
number = int(input("Enter a number to find it's table"))

for i in range(1,11):
    print(number,"*",i,"=",i*number)
# Out:
# Enter a number to find it's table 5
# 5 * 1 = 5
# 5 * 2 = 10
# 5 * 3 = 15
# 5 * 4 = 20
# 5 * 5 = 25
# 5 * 6 = 30
# 5 * 7 = 35
# 5 * 8 = 40
# 5 * 9 = 45
# 5 * 10 = 50

# %%
number = int(input("Enter a number to find it's table"))
print(number)

# for i in range(1,11):
#     print(number,"*",i,"=",i*number)
# Out:
# Enter a number to find it's table 1
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 number = list(int(input("Enter a number to find it's table")))
#       2 print(number)
#       4 # for i in range(1,11):
#       5 #     print(number,"*",i,"=",i*number)
#
# TypeError: 'int' object is not iterable
