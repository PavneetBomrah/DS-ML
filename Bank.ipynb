# %%
#Real World virtual atm machine minor project

balance = 10000
pin = 6969
print("\t\tWelcome to Apna Bank\n\n")
if 'card'==input("Enter your card"):
    option = 0
    if pin == int(input("Enter your Pin")):
        choice = 'y'
        while choice == 'y':
            print("Enter your task to perform:\n")
            print("\t 1) Check Balance")
            print("\t 2) Deposit")
            print("\t 3) Withdraw")
            print("\t 0) Exit\n\n\n")
            option = int(input("Enter your choice"))
            if option >= 0 and option <=4 :
                match option:
                    case 1:
                        choice = 'y'
                        print("Balance: ",balance,"\n\n\n")
                    case 2:
                        choice = 'y'
                        balance += int(input("Enter value to Deposit:"))
                        print("New Balance: ",balance,"\n\n\n")
                    case 3:
                        choice = 'y'
                        balance -= int(input("Enter value to Withdraw:"))
                        print("New Balance: ",balance,"\n\n\n")
                    case 0:
                        choice = 'n'
            else:
                print("Invalid Choice retry")
    else:
        print("Invalid Pin")
    
else:
    print("invalid card")
# Out:
# 		Welcome to Apna Bank
# Enter your card card
# Enter your Pin 6969
# Enter your task to perform:
#
# 	 1) Check Balance
# 	 2) Deposit
# 	 3) Withdraw
# 	 0) Exit
# Enter your choice 3
# Enter value to Withdraw: 1000
# New Balance:  9000
#
#
#
# Enter your task to perform:
#
# 	 1) Check Balance
# 	 2) Deposit
# 	 3) Withdraw
# 	 0) Exit
# Enter your choice 2
# Enter value to Deposit: 6969690
# New Balance:  6978690
#
#
#
# Enter your task to perform:
#
# 	 1) Check Balance
# 	 2) Deposit
# 	 3) Withdraw
# 	 0) Exit
# Enter your choice 2
# Enter value to Deposit: j
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 24
#      22 case 2:
#      23     choice = 'y'
# ---> 24     balance += int(input("Enter value to Deposit:"))
#      25     print("New Balance: ",balance,"\n\n\n")
#      26 case 3:
#
# ValueError: invalid literal for int() with base 10: 'j'
