# %%
# what is python?
# :- python is an interpreter and high level language.
# :- easy to learn
# :- interpreter based language
# :- dynamic typed :- get the data type during exc
#    static type :- before exc
# :- inbuilt library
# :- strong typed 
# :- high level 
# :- case sensitive language

# %%
print('hi all')
print('hlo')
dskjlhbfkjads
print('all')

# %%
# # data type 
# user define and builtin 
# builtin:-
# number:- int,float,complex
# text:- string
# list
# dict
# set
# tuple
# dic
# boolean

# %%
help('keywords')

# %%
# a,b,c=10,20,30
# print(a,b,c)
d=40
e=50
print(d)
print(e)

# %%
a=b=c=d=20
print(a)

# %%
# a,b,c='ram'
e,d,t=123
# print(b)
print(d)

# %%
a,b,c,d='ram'
print(b)

# %%
# nameerror
print(rahul)

# %%
# syntax error
print('hi all)

# %%
45a=20

# %%
a=20
b=30
print(a)
b
a
print(b)
# Out:
# 20
# 30

# %%
d=50
d
print(20)
g=60
d
# Out:
# 20
# 50

# %%
a=10
print(a)
b=20j
print(b)
print(type(b))
# Out:
# 10
# 20j
# <class 'complex'>

# %%
# string
a='raman
kdsflkghl'
print(a)
b="#$%^7"
c='''123456
DKLFSHGLKDFS;LGKSDJ'''
print(c)

# %%
a="it's my birthday"
print(a)

# %%
# string :- mutable and immutable
a='raman'
print(id(a))
a='rahul'
print(id(a))

# %%
c=[1,2,3]
print(id(c))
c.append(4)
print(id(c))

# %%
# indexing
# a='IITM'
 # 0123
# accessing the value from string.
# print(a[2])
# positive indexing
# print(a[-4])
# slicing 
a='python'
 # 012345
     # -1
print(a[-2:-7:-2])
print(a[0:5:2])
print(a[2:6:])
print(a[0:6:5])
# print(a[startpoint:endpoint:steppoint/skip])
#         0            end of the value

# %%
# python
# py,to,tn,yn,np,oy,yo,ny,nhy,ph

# %%
dir('string')

# %%
# methods
a='python'
print(a.upper())

# %%
b='RAHUL'
print(b.lower())

# %%
a='python'
b=a.index('r')
print(b)

# %%
a='python'
print(a.find('r'))

# %%
a='python'
print(a.replace('p','t'))

# %%
a='pythonp'
print(a.count('p'))

# %%
# operators
# arithmetic:- +,-,*,**,/,//,%
print(10+10)
print(10*5)
print(2**2)
print(10/2)
print(10//2)
# assigment
a=10
a+=1 
print(a)
# comparison
print(10!=100)
# logical
# and or not
# t and t= t
# t and f= f 
# f and f= f

# t or t =t
# t or f = t
# f or t = t
# f or f = f

# membership
# in not in 
var='python'
print('7' not in  var)

# %%
print(not(0 or 1))

# %%
t=[1,2,3,'raman',5.4]
print(id(t))
t.append(8)
print(id(t))

# %%
t=[1,2,3,'raman',5.4]
   # 0 1 2  3       4 
# accessing the value from list
print(t[3][2::])

# %%
# nested list
r=[[23,3],343,34,[[34,345,[3434,[34,[[[2344,'python']]]]]]]]
print(r)

# %%
g=[32,23,[['raman'],['abc']]]
print(g[2][1][0][2])

# %%
# append(x)	Adds item x to the end
time=[1,2,3,4,5]
# a=[] empty list
# time.append(6)
# print(time)
# insert(i, x)	Inserts x at index i
time=[1,2,3,4,5]
# time.insert(3,8)
# print(time)
# extend(iterable)	Adds multiple elements

# y=[9,10,11]
# y.extend(time)
# print(y)
# remove(x)	Removes first occurrence of x
# time=[1,2,3,4,5]
# time.remove(3)
# print(time)
# pop([i])	Removes and returns item at index i (default: last)
# time=[1,2,3,4,5]
# time.pop(0)
# print(time)
# index(x)	Returns index of first x
rt=[1,2,3,4,5]
rt.index(3)
print(rt)
# count(x)	Counts occurrences of x

# %%
e=[1,2,2,3,4,5]
print(e.count(2))

# %%
dir('list')

# %%
u=[1,2,3,4,53,55,5]
print(len(u))
g='raman'
print(len(g))

# %%
# mutable and immutable
a='python'
print(id(a))
a='students'
print(id(a))
0

# %%
time='hi all this raman'
print(id(time))
a=time
a+='and rahul'
print(id(a))

# %%
t=[1,2,3,4,5]
print(id(t))
t.append(6)
print(id(t))
print(t)

# %%
# list
t=[] #empty
# list allow multiple data type
g=[1,4.5,'python']
# accessing the value through the indexing
# print(g[2])
# print(g[2][2:6:1])

# %%
# nested list
r=[1,2,3,[],34,[[3,6,]]]
print(r[5][0][1])

# %%
# # dir('list')
# 🔹 Features:
# •	Ordered
# •	Mutable (changeable)
# •	Allows duplicates
# •	Elements are indexed (0-based)
________________________________________

# %%
# Method	Description
# append(x)	Adds item x to the end
st=[1,2,3,4,5]
# st.append(6)
# print(st)

# insert(i, x)	Inserts x at index i
st=[1,2,3,4,5]
# st.insert(0,'raman')
# print(st)

# extend(iterable)	Adds multiple elements
st=[1,2,3,4,5]
# t=[6,7,8]
# t.extend(st)
# print(t)


# remove(x)	Removes first occurrence of x
st=[1,2,3,4,5]
# st.remove(5)
# print(st)
# pop([i])	Removes and returns item at index i (default: last)
st=[1,2,3,4,5]
# st.pop(3)
# print(st)
# index(x)	Returns index of first x
# count(x)	Counts occurrences of x
# e=[1,2,3,4,5,1,2,1]
# print(e.count(1))

# %%
if 100==100:
    print('this is true')
    if 500!=500:
        print('ohkay')
    else:
        print('false')
elif 20076476==200:
    print('hi all')
else:
    print('this is not true')

# %%
if 200==200:
    print('hi all')
elif 300==300:
    print('good')
else:
    print('wow')

# %%
# real world virtual atm machine minor project

# %%
# a=int(input('enter your value'))
# typecasting
# Out:
# enter your value kjv
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 a=int(input('enter your value'))
#
# ValueError: invalid literal for int() with base 10: 'kjv'

# %%
# real world virtual atm machine minor project

amount=10000
pin=1234
print('\t\t\t\t\t\t\tWelcome to HDFC ATM')
if 'card'==input('Insert your card'):
    print('welcome')
    if pin==int(input('Enter your pin')):
        print('\t\t\t\t\t\t\t1) check balance\n\t\t\t\t\t\t\t2) cash withdraw')
        option=int(input('Select your option'))
        if option==1:
            print('your current balance is :-  ',amount)
        elif option==2:
            user_amount=int(input('Enter your amount'))
            print('your current balance is:- ',amount-user_amount)
        else:
            print('Invalid input')
    else:
        print('Wrong pin')
else:
    print('Invalid card')
# Out:
# 							Welcome to HDFC ATM
# Insert your card card
# welcome
# Enter your pin 1234
# 							1) check balance
# 							2) cash withdraw
# Select your option 2
# Enter your amount 1000
# your current balance is:-  9000

# %%
# a=1234
# print(a[2])
# b='123'
# print(b[2])

# %%
for father in 'abc':
    print(father)
    for child in 'def':
        print(child)
    for j in 'jhf':
        print('j')
# Out:
# a
# d
# e
# f
# j
# j
# j
# b
# d
# e
# f
# j
# j
# j
# c
# d
# e
# f
# j
# j
# j

# %%
# a=[1,2,3,4,5]
# d=[45,75,[[]],[]]
# back
# b:-2
# a:-1
# c:-3
# k:-11

# %%
# i = 1
# while i < 6:
#   print(i)
#   i += 1

# i = 1
# while i < 6:
#   print(i)
#   if i == 2:
#     break
#   i += 1

i = 0
while i < 6:
  i += 1
  if i == 2:
    continue
  print(i)
# Out:
# 1
# 3
# 4
# 5
# 6

# %%
# function
def abc(): #parameters
    print('hi all')
abc()
# Out:
# hi all

# %%
abc()
# Out:
# hi all

# %%
# function with parameter'
def a(a,b):
    print(a+b)
a(5,10) #argument
# Out:
# 15

# %%
# function with default parameter
# def b(name='rahul'):
#     print('hi ',name)
# b('raman')
# Out:
# hi  raman

# %%
# calling the function inside the another function
def abc():
    print(12345)
def ert():
    print(324325)
    abc()
ert()
# Out:
# 324325
# 12345

# %%
# # nested funtion
# def t():
#     print('hi')
#     def y():
#         print('hello')
#     # t()

# t()
# Out:
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# ...

# %%
def profile(**info):
   print(info['name'])

profile(name="Ravi", age=22, course="B.Tech")
d-read
write- w
append- a
# Out:
# Ravi

# %%
a=open(r'C:\Users\raman\Desktop\iitm_test_file.txt','')
a.write('   hi class ab dekho read karke')
a.close()

# %%
a=open(r'C:\Users\raman\Desktop\iitm_test_file.txt','x')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 a=open(r'C:\Users\raman\Desktop\iitm_test_file.txt','x')
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileExistsError: [Errno 17] File exists: 'C:\\Users\\raman\\Desktop\\iitm_test_file.txt'

# %%
pip install mysql-connector-python
import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="yourusername",
  password="yourpassword"
)

mycursor = mydb.cursor()

mycursor.execute("CREATE DATABASE mydatabase")
